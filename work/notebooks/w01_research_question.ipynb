# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Shvuz/Serhat_Yavuz/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# My lane: Refresh / Content Opportunity Scoring.
#
# I already ran the starter pipeline (notebooks 01 and 02), which showed that a learned model can outperform a simple hand-written rule at identifying pages worth reviewing first. This lane builds directly on that foundation — designing a ranked review queue with transparent reason codes, rather than starting from scratch with a less familiar problem type. The starter dataset also ships everything I need to prototype this lane immediately.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Decision: which content pages a reviewer looks at first, out of thousands, when they only have limited time each week.
#
# Action: the reviewer opens the top-ranked pages and decides whether to refresh, expand, protect, prune, or monitor each one.
#
# Cost of a wrong call: if the model flags the wrong pages, reviewer time is wasted on pages that didn't need attention, while pages that were actually declining go unreviewed. This is a real but recoverable cost, since a human still makes the final decision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/Shvuz/Serhat_Yavuz"
REPO_DIR = "Serhat_Yavuz"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

print("Working dir:", os.getcwd())

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

stale_visible = ((df["days_since_last_update"] >= 180) & (df["impressions_90d"] >= 500)).sum()
print(f"Pages that are stale AND still visible: {stale_visible} out of {len(df)}")

declining_rate = (df["trend_direction"].str.lower() == "down").mean()
print(f"Overall declining rate: {declining_rate:.1%}")

med_by_trend = df.groupby("trend_direction")["impressions_90d"].median()
print("Median impressions_90d by trend_direction:")
print(med_by_trend.round(0))
# Out:
# Working dir: /content/Serhat_Yavuz/Serhat_Yavuz/Serhat_Yavuz
# Pages that are stale AND still visible: 17 out of 30000
# Overall declining rate: 54.2%
# Median impressions_90d by trend_direction:
# trend_direction
# down       961.0
# flat         4.0
# new          3.0
# stable    1944.0
# up         587.0
# Name: impressions_90d, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# I can claim: which pages show observable patterns of staleness, low CTR, or declining trend, based on measured signals — and I can produce a ranked, evidence-backed list a reviewer can inspect and act on.
#
# I cannot claim: that refreshing a flagged page will cause it to recover (that needs a controlled experiment, not observational data), any Google algorithm factor, or that my model is "correct" in an absolute sense — only that it beats a transparent baseline on a defined metric, on this dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
